# %%
import pandas as pd
#check details for file 1
df = pd.read_csv("../../data/gene expression/1_4_hpa_rna_celline.tsv", sep="\t")
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (24315372, 6)
# ['Gene', 'Gene name', 'Cell line', 'TPM', 'pTPM', 'nTPM']
#               Gene Gene name Cell line   TPM  pTPM  nTPM
# 0  ENSG00000000003    TSPAN6      143B  22.0  27.6  25.9
# 1  ENSG00000000003    TSPAN6     22Rv1   2.8   3.6   2.7
# 2  ENSG00000000003    TSPAN6  23132/87   6.2   7.5   7.5
# 3  ENSG00000000003    TSPAN6      253J  14.2  18.7  25.4
# 4  ENSG00000000003    TSPAN6   253J-BV  13.0  17.1  18.5

# %%
#check details for file 2
df = pd.read_csv("../../data/gene expression/2_DepMap_OmicsExpressionAllGenesTPMLogp1Profile.csv", index_col=0)
print(df.shape)
df.head()
# Out:
# (1495, 53961)
#            TSPAN6 (ENSG00000000003)  TNMD (ENSG00000000005)  \
# PR-AdBjpG                  4.331992                0.000000
# PR-I2AzwG                  4.567424                0.584963
# PR-5ekAAC                  3.150560                0.000000
# PR-I21681                  5.085340                0.000000
# PR-i9DRP1                  6.729417                0.000000
#
#            DPM1 (ENSG00000000419)  SCYL3 (ENSG00000000457)  \
# PR-AdBjpG                7.364660                 2.792855
# PR-I2AzwG                7.106641                 2.543496
# PR-5ekAAC                7.379118                 2.333424
# PR-I21681                7.154211                 2.545968
# PR-i9DRP1                6.537917                 2.456806
#
#            C1orf112 (ENSG00000000460)  FGR (ENSG00000000938)  \
# PR-AdBjpG                    4.471187               0.028569
# PR-I2AzwG                    3.504620               0.000000
# ...

# %%
# peek at the header first without loading the whole thing for file 3
with open("../../data/gene expression/3_GEOexpression.txt") as f:
    first_line = f.readline()
print("First line (first 300 chars):", first_line[:300])
# Out:
# First line (first 300 chars): Gene	GSM101610	GSM101615	GSM101616	GSM101667	GSM101668	GSM101671	GSM101672	GSM101673	GSM101674	GSM101675	GSM101676	GSM101677	GSM101678	GSM101679	GSM101680	GSM101685	GSM101686	GSM101687	GSM101688	GSM1017454	GSM1017455	GSM1017456	GSM1017457	GSM1017458	GSM1017459	GSM1017460	GSM1017461	GSM1017462	GSM101

# %%
#check details for file 3
geo = pd.read_csv("../../data/gene expression/3_GEOexpression.txt", sep="\t")
print(geo.shape)
print(geo.columns.tolist()[:10])   # first 10 column names
geo.iloc[:5, :5]
# Out:
# (19914, 3268)
# ['Gene', 'GSM101610', 'GSM101615', 'GSM101616', 'GSM101667', 'GSM101668', 'GSM101671', 'GSM101672', 'GSM101673', 'GSM101674']
#               Gene    GSM101610    GSM101615    GSM101616    GSM101667
# 0  ENSG00000000003    33.615700   553.249756   540.452209   599.431152
# 1  ENSG00000000005    40.925682    31.327406    33.934967    34.213123
# 2  ENSG00000000419  2182.281250  3419.430420  3514.540039  2295.817383
# 3  ENSG00000000457    58.934814    95.068222    94.900459    51.810070
# 4  ENSG00000000460   136.418900   257.929169   271.317230   162.090073

# %%
#check details for file 4
df = pd.read_csv("../../data/gene expression/4_Harmonized_MS_CCLE_Gygi_subsetted.csv", index_col=0)
print(df.shape)
print(df.columns.tolist()[:5])   # first few column names
df.iloc[:5, :5]
# Out:
# (375, 12558)
# ['A0AV96 (RBM47)', 'A0AVF1 (IFT56)', 'A0AVG3 (TSNARE1)', 'A0AVI4 (TMEM129)', 'A0AVK6 (E2F8)']
#             A0AV96 (RBM47)  A0AVF1 (IFT56)  A0AVG3 (TSNARE1)  \
# ACH-000849        0.358567       -0.172066               NaN
# ACH-000441       -1.112410        0.339446               NaN
# ACH-000248        0.855575       -0.181171               NaN
# ACH-000684        0.061377       -0.341233               NaN
# ACH-000856        0.284258       -0.059558               NaN
#
#             A0AVI4 (TMEM129)  A0AVK6 (E2F8)
# ACH-000849               NaN            NaN
# ACH-000441               NaN            NaN
# ACH-000248               NaN            NaN
# ACH-000684               NaN            NaN
# ACH-000856               NaN            NaN

# %%
#check details for file 5
df = pd.read_csv("../../data/gene properties/5_OmicsFusionFilteredSupplementary.csv")
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (184237, 30)
# ['Unnamed: 0', 'SequencingID', 'ModelID', 'IsDefaultEntryForModel', 'ModelConditionID', 'IsDefaultEntryForMC', 'CanonicalFusionName', 'gene1(ENS ID)', 'gene2(ENS ID)', 'TotalReadsInSample', 'TotalReadsSupportingFusion', 'FFPM', 'confidence', 'split_reads1', 'split_reads2', 'discordant_mates', 'strand1(gene/fusion)', 'strand2(gene/fusion)', 'reading_frame', 'breakpoint1', 'breakpoint2', 'site1', 'site2', 'type', 'coverage1', 'coverage2', 'tags', 'retained_protein_domains', 'direction1', 'direction2']
#    Unnamed: 0 SequencingID     ModelID IsDefaultEntryForModel  \
# 0           0   CDS-010xbm  ACH-001113                    Yes
# 1           1   CDS-010xbm  ACH-001113                    Yes
# 2           2   CDS-010xbm  ACH-001113                    Yes
# 3           3   CDS-010xbm  ACH-001113                    Yes
# 4           4   CDS-010xbm  ACH-001113                    Yes
#
#   ModelConditionID IsDefaultEntryForMC CanonicalFusionName  \
# ...

# %%
#check details for file 6
df = pd.read_csv("../../data/gene properties/6_OmicsSomaticMutationsProfile.csv")
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15588\4206586948.py:2: DtypeWarning: Columns (22,50,54,56,57,58,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data/gene properties/6_OmicsSomaticMutationsProfile.csv")
# (1066869, 70)
# ...

# %%
#check details for file 7
df = pd.read_csv("../../data/nomenclature/7_cellosaurus.csv")
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (152231, 17)
# ['Identifier (cell line name)', 'Accession (CVCL_xxxx)', 'Secondary accession number(s)', 'Synonyms', 'Cross-references', 'References identifiers', 'Web pages', 'Comments', 'STR profile data', 'Diseases', 'Species of origin', 'Hierarchy', 'Originate from same individual', 'Sex of cell', 'Age of donor at sampling', 'Category', 'Date (entry history)']
#   Identifier (cell line name) Accession (CVCL_xxxx)  \
# 0            #132 PC3-1-SC-E8             CVCL_B0T9
# 1             #132 PL12 SC-D1             CVCL_B0T8
# 2                   #15310-LN             CVCL_E548
# 3                      #16-15             CVCL_KA96
# 4                        #40a             CVCL_IW91
#
#   Secondary accession number(s)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                             Synonyms  \
# ...

# %%
#check details for file 8
df = pd.read_csv("../../data/nomenclature/8_DepMap_OmicsProfiles.csv")
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (3830, 5)
# ['ProfileID', 'ModelCondition', 'ModelID', 'Datatype', 'WESKit']
#    ProfileID  ModelCondition     ModelID Datatype WESKit
# 0  PR-00UtU3  MC-001131-kkJv  ACH-001131      wgs    NaN
# 1  PR-01r7OM  MC-000957-Yckn  ACH-000957      rna    NaN
# 2  PR-02XmLG  MC-002785-qo9e  ACH-002785      rna    NaN
# 3  PR-04VvBz  MC-001289-BpdI  ACH-001289      wes    ICE
# 4  PR-09gmEI  MC-000520-YIm7  ACH-000520      rna    NaN

# %%
#check details for file 9
df = pd.read_csv("../../data/nomenclature/9_DepMap_sample_info.csv")
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (1840, 29)
# ['DepMap_ID', 'cell_line_name', 'stripped_cell_line_name', 'CCLE_Name', 'alias', 'COSMICID', 'sex', 'source', 'RRID', 'WTSI_Master_Cell_ID', 'sample_collection_site', 'primary_or_metastasis', 'primary_disease', 'Subtype', 'age', 'Sanger_Model_ID', 'depmap_public_comments', 'lineage', 'lineage_subtype', 'lineage_sub_subtype', 'lineage_molecular_subtype', 'default_growth_pattern', 'model_manipulation', 'model_manipulation_details', 'patient_id', 'parent_depmap_id', 'Cellosaurus_NCIt_disease', 'Cellosaurus_NCIt_id', 'Cellosaurus_issues']
#     DepMap_ID cell_line_name stripped_cell_line_name  \
# 0  ACH-000016         SLR 21                   SLR21
# 1  ACH-000032     MHH-CALL-3                MHHCALL3
# 2  ACH-000033      NCI-H1819                NCIH1819
# 3  ACH-000043       Hs 895.T                  HS895T
# 4  ACH-000049         HEK TE                   HEKTE
#
#                                      CCLE_Name alias  COSMICID     sex  \
# ...

# %%
#check details for file 10
geoinfo = pd.read_csv("../../data/nomenclature/10_GEOInfo.txt", sep="\t")
print(geoinfo.shape)
print(geoinfo.columns.tolist())
geoinfo.head()
# Out:
# (3267, 23)
# ['Geo_accession', 'CEL_file_names', 'title', 'status', 'submission_date', 'last_update_date', 'type', 'channel_count', 'source_name_ch1', 'organism_ch1', 'characteristics_ch1', 'platform_id', 'contact_country', 'contact_institute', 'GSE_ID', 'GSE_filename', 'cell_line', 'disease', 'origin', 'Cellosaurus_ID', 'Cellline', 'Matching_Type', 'cell_line_Trimmed']
#   Geo_accession CEL_file_names title status submission_date last_update_date  \
# 0     GSM101610      GSM101610   NaN    NaN             NaN              NaN
# 1     GSM101615      GSM101615   NaN    NaN             NaN              NaN
# 2     GSM101616      GSM101616   NaN    NaN             NaN              NaN
# 3     GSM101667      GSM101667   NaN    NaN             NaN              NaN
# 4     GSM101668      GSM101668   NaN    NaN             NaN              NaN
#
#   type  channel_count source_name_ch1 organism_ch1  ... contact_institute  \
# ...

# %%
#check details for file 11
df = pd.read_csv("../../data/nomenclature/11_hpa_rna_celline_description.tsv", sep="\t")
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (1206, 7)
# ['Cell line', 'Disease', 'Disease subtype', 'Cellosaurus ID', 'Patient', 'Primary/Metastasis', 'Sample collection site']
#   Cell line          Disease Disease subtype Cellosaurus ID   Patient  \
# 0      143B      Bone cancer    Osteosarcoma      CVCL_2270        13
# 1     22Rv1  Prostate cancer  Adenocarcinoma      CVCL_1045      Male
# 2  23132/87   Gastric cancer  Adenocarcinoma      CVCL_1046  Male, 72
# 3      253J   Bladder cancer       Carcinoma      CVCL_7935  Male, 53
# 4   253J-BV   Bladder cancer       Carcinoma      CVCL_7937  Male, 53
#
#   Primary/Metastasis Sample collection site
# 0            Primary                   bone
# 1            primary               prostate
# 2            primary                stomach
# 3         metastasis             lymph node
# 4         metastasis             lymph node

# %%
#check details for file 12
metabolomics = pd.read_csv("../../data/non gene expression/12_CCLE_metabolomics_20190502.csv")
# fix the one missing ACH ID
#metabolomics.loc[metabolomics["CCLE_ID"] == "OC315_OVARY", "DepMap_ID"] = "ACH-001144"
print(metabolomics.shape)
metabolomics.head()
# Out:
# (928, 227)
#                                     CCLE_ID   DepMap_ID  2-aminoadipate  \
# 0                                DMS53_LUNG  ACH-000698        6.112727
# 1                    SW1116_LARGE_INTESTINE  ACH-000489        5.577413
# 2                             NCIH1694_LUNG  ACH-000431        5.886398
# 3  P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000707        5.770030
# 4  HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000509        5.480683
#
#    3-phosphoglycerate  alpha-glycerophosphate  4-pyridoxate  aconitate  \
# 0            6.034198                5.896896      6.000532   5.513618
# 1            5.727045                5.111468      6.073250   5.802494
# 2            5.574881                5.541259      5.848375   5.665026
# 3            6.099229                6.233259      5.543495   5.767759
# 4            5.469742                6.509397      6.251005   5.190578
#
#     adenine   adipate  alpha-ketoglutarate  ...  C56:8 TAG  C56:7 TAG  \
# ...

# %%
#check details for file 13
from cmapPy.pandasGEXpress.parse import parse

mirna_gct = parse("../../data/non gene expression/13_CCLE_miRNA_20181103.gct")
mirna = mirna_gct.data_df.copy()
mirna.index = mirna_gct.row_metadata_df["Description"]   # real miRNA names
mirna.index.name = "miRNA"
print(mirna.shape)
mirna.iloc[:5, :5]
# note: cell-line columns still CCLE names here — harmonise to ACH as a next step
# Out:
# C:\Users\HP\miniconda3\envs\text_analytics\Lib\site-packages\cmapPy\pandasGEXpress\parse_gct.py:251: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   row_metadata = row_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# C:\Users\HP\miniconda3\envs\text_analytics\Lib\site-packages\cmapPy\pandasGEXpress\parse_gct.py:277: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   col_metadata = col_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# (734, 954)
# cid          DMS53_LUNG  SW1116_LARGE_INTESTINE  NCIH1694_LUNG  \
# miRNA
# hsa-let-7a  4362.580078             5191.500000   24991.050781
# hsa-let-7b   187.440002              868.219971    5066.089844
# hsa-let-7c   267.029999              244.880005     818.489990
# ...

# %%
#check details for file 14
signatures = pd.read_csv("../../data/non gene expression/14_OmicsGlobalSignatures.csv")
sig_cols = ["ModelID", "MSIScore", "LoHFraction", "WGD", "CIN", "Ploidy", "Aneuploidy"]
signatures_clean = signatures[signatures["IsDefaultEntryForModel"] == "Yes"][sig_cols].copy()
signatures_clean = signatures_clean.set_index("ModelID")
print(signatures_clean.shape)
signatures_clean.head()
# Out:
# (1955, 6)
#             MSIScore  LoHFraction  WGD       CIN    Ploidy  Aneuploidy
# ModelID
# ACH-000839      3.68     0.107443  1.0  0.502634  3.158291        20.0
# ACH-000041      2.21     0.130089  1.0  0.523865  3.236089        19.0
# ACH-002046      2.87     0.222342  1.0  0.679772  3.326715        30.0
# ACH-002048      2.48          NaN  NaN       NaN       NaN         NaN
# ACH-000042      2.07          NaN  NaN       NaN       NaN         NaN
